# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
golden_gate = cv2.imread('golden gate.JPG',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(golden_gate,cmap='gray')

# %%
golden_gate.shape
# Out:
# (3561, 5639)

# %%
golden_gate = cv2.imread('golden gate.JPG',cv2.IMREAD_COLOR)

# %%
golden_gate.shape
# Out:
# (3561, 5639, 3)

# %%
golden_gate_RGB = cv2.cvtColor(golden_gate, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(golden_gate)
plt.show()

# %% [markdown]
# # Saving image

# %%
golden_gate = cv2.imread('golden gate.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imwrite('golden gate b&w.jpg',golden_gate)
# Out:
# True

# %% [markdown]
# # Resizing Images

# %%
golden_gate_50x50 = cv2.resize(golden_gate,(1920,1080))

# %%
plt.imshow(golden_gate_50x50)

# %% [markdown]
# # Cropping image

# %%
plt.imshow(golden_gate[:,:2500])

# %% [markdown]
# # Image kernel/filter operation

# %%
blurring_kernel = np.ones((5,5))/25

# %%
blurring_kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
filtered_image = cv2.filter2D(golden_gate, -1, blurring_kernel)

# %%
plt.imshow(filtered_image,cmap='gray')

# %%
help(cv2.filter2D)
# Out:
# Help on built-in function filter2D:
#
# filter2D(...)
#     filter2D(src, ddepth, kernel[, dst[, anchor[, delta[, borderType]]]]) -> dst
#     .   @brief Convolves an image with the kernel.
#     .
#     .   The function applies an arbitrary linear filter to an image. In-place operation is supported. When
#     .   the aperture is partially outside the image, the function interpolates outlier pixel values
#     .   according to the specified border mode.
#     .
#     .   The function does actually compute correlation, not the convolution:
#     .
#     .   \f[\texttt{dst} (x,y) =  \sum _{ \substack{0\leq x' < \texttt{kernel.cols}\\{0\leq y' < \texttt{kernel.rows}}}}  \texttt{kernel} (x',y')* \texttt{src} (x+x'- \texttt{anchor.x} ,y+y'- \texttt{anchor.y} )\f]
#     .
#     .   That is, the kernel is not mirrored around the anchor point. If you need a real convolution, flip
#     .   the kernel using #flip and set the new anchor to `(kernel.cols - anchor.x - 1, kernel.rows -
# ...

# %%
list(map(lambda x: 1/(1+np.exp(-x)), [45,1,56,78,78]))
# Out:
# [1.0, 0.7310585786300049, 1.0, 1.0, 1.0]

# %%
np.vectorize(lambda x: 1/(1+np.exp(-x)))([45,1,56,78,78])
# Out:
# array([1.        , 0.73105858, 1.        , 1.        , 1.        ])

# %%
list(filter(lambda x: True if x%2 == 0 else False, [1,2,3,4]))
# Out:
# [2, 4]

# %%
from functools import reduce

# %%
reduce(lambda a,b: a+b, [1,2,3,4,5])
# Out:
# 15

# %% [markdown]
# # There are some advanced techniques, we will get back to them later on

# %% [markdown]
# # Until then see you next time

# %% [markdown]
# # Bye bye
